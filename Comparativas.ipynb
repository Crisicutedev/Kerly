# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("ventas.xlsx")
df
# Out:
#          #  FACTURA_ID       FECHA  ESTABLECIMIENTO  \
# 0        1      984043  07/05/2025  Comercial Kerly
# 1        2      983811  07/05/2025  Comercial Kerly
# 2        3      983471  06/05/2025  Comercial Kerly
# 3        4      983471  06/05/2025  Comercial Kerly
# 4        5      983471  06/05/2025  Comercial Kerly
# ...    ...         ...         ...              ...
# 1742  1743       60127  10/06/2021  Comercial Kerly
# 1743  1744       60107  09/06/2021  Comercial Kerly
# 1744  1745       60067  09/06/2021  Comercial Kerly
# 1745  1746       60041  09/06/2021  Comercial Kerly
# 1746  1747       60040  09/06/2021  Comercial Kerly
#
#                         CATEGORIA          CODIGO  \
# 0     ELECTRODOMESTICOS Y MUEBLES        US16058A
# 1                   HIGIENE-HOGAR        RF1LTDFT
# 2                   HIGIENE-HOGAR        RF1LTDFT
# 3                   HIGIENE-HOGAR    RF1LT.DS.LAV
# 4                   HIGIENE-HOGAR   RF1LT.DS.ECOP
# ...                           ...             ...
# 1742        Lavadoras y Secadoras    8MWTWLA41WJG
# 1743               Refrigeración          WT1818A
# 1744               Refrigeración             M229
# 1745                   TV y Video          32S62I
# 1746                   TV y Video  UN55NU7090PXPA
#
#                                     AGRUPAR_POR  COLOR  TALLA  TIPO  ...  \
# 0                Ventilador de piso 110 voltios    NaN    NaN  BIEN  ...
# 1     Refill Litro de Detergente Fresco Textil.    NaN    NaN  BIEN  ...
# 2     Refill Litro de Detergente Fresco Textil.    NaN    NaN  BIEN  ...
# 3     Refill Litro Desinfectante aroma Lavanda.    NaN    NaN  BIEN  ...
# 4           Refill Litro Desinfectante EcoPino.    NaN    NaN  BIEN  ...
# ...                                         ...    ...    ...   ...  ...
# 1742               Lavadora carga superior 53Lb    NaN    NaN  BIEN  ...
# 1743                      Refrigeradora 18 pies    NaN    NaN  BIEN  ...
# 1744                                  Ecofiltro    NaN    NaN  BIEN  ...
# 1745                          Televisor LED 32"    NaN    NaN  BIEN  ...
# 1746                    Televisor de 55" 4k UHD    NaN    NaN  BIEN  ...
#
#      PACIENTE  CANTIDAD  COSTO COSTO TOTAL  DESCUENTO   TOTAL  UTILIDAD  \
# 0         NaN       1.0    NaN         NaN        0.0   175.0     60.00
# 1         NaN       4.0    NaN         NaN        0.0    32.0     24.00
# 2         NaN       6.0    NaN         NaN        0.0    48.0     36.00
# 3         NaN       2.0    NaN         NaN        0.0    14.0     10.00
# 4         NaN       5.0    NaN         NaN        0.0    30.0     20.00
# ...       ...       ...    ...         ...        ...     ...       ...
# 1742      NaN       1.0    NaN         NaN        0.0  2300.0    300.01
# 1743      NaN       1.0    NaN         NaN        0.0  4300.0   2435.00
# 1744      NaN       1.0    NaN         NaN        0.0   250.0      0.00
# 1745      NaN       1.0    NaN         NaN        0.0  2432.0   1682.00
# 1746      NaN       1.0    NaN         NaN        0.0  7224.0   4574.00
#
#          ESTADO                            VENDEDOR     CAJERO
# 0     Facturada                      Lusvin Samayoa    Ckadmin
# 1     Facturada  Jeaqueline Aracely Lopez Marroquin  Ckventas2
# 2     Facturada     Katheryn Celeste Rosales Monzon  Ckventas1
# 3     Facturada     Katheryn Celeste Rosales Monzon  Ckventas1
# 4     Facturada     Katheryn Celeste Rosales Monzon  Ckventas1
# ...         ...                                 ...        ...
# 1742  Facturada                      Lusvin Samayoa    Ckadmin
# 1743  Facturada     Katheryn Celeste Rosales Monzon  Ckventas1
# 1744  Facturada         Lesly Yasmin Gabriela Ramos  Ckventas2
# 1745  Facturada                      Lusvin Samayoa    Ckadmin
# 1746  Facturada                      Lusvin Samayoa    Ckadmin
#
# [1747 rows x 29 columns]

# %%
# ventas por dia y beneficio
df["FECHA"] = pd.to_datetime(df["FECHA"], dayfirst=True)
df["Day"] = df['FECHA'].dt.day_name()
sns.barplot(data=df, x="Day", y="TOTAL", errorbar=None)
plt.title("Fechas vs Ventas")
plt.xticks(rotation=90)
plt.show()
